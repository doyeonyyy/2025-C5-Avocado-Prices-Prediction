# %%
import pandas as pd

dataset = pd.read_csv("/Users/doyeonkim/Downloads/avocado.csv")
dataset.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
dataset.tail()
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046     4225  \
# 18244           7  2018-02-04          1.63      17074.83  2046.96  1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70  3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92  2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63  2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77  2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    0.00    13498.67    13066.82      431.85          0.0  organic  2018
# 18245    0.00     9264.84     8940.04      324.80          0.0  organic  2018
# 18246  727.94     9394.11     9351.80       42.31          0.0  organic  2018
# 18247  727.01    10969.54    10919.54       50.00          0.0  organic  2018
# 18248  224.53    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %%
dataset.drop('Unnamed: 0',axis=1,inplace=True)

# %%
dataset.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %%
dataset['Date']=pd.to_datetime(dataset['Date'])
dataset['Month']=dataset['Date'].apply(lambda x:x.month)
dataset['Day']=dataset['Date'].apply(lambda x:x.day)
dataset.head()
# Out:
#         Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0 2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1 2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2 2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3 2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4 2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0     8696.87     8603.62       93.25          0.0  conventional  2015
# 1     9505.56     9408.07       97.49          0.0  conventional  2015
# 2     8145.35     8042.21      103.14          0.0  conventional  2015
# 3     5811.16     5677.40      133.76          0.0  conventional  2015
# 4     6183.95     5986.26      197.69          0.0  conventional  2015
#
#    region  Month  Day
# 0  Albany     12   27
# 1  Albany     12   20
# 2  Albany     12   13
# 3  Albany     12    6
# 4  Albany     11   29

# %%
import matplotlib.pyplot as plt

byDate=dataset.groupby('Date').mean(numeric_only=True)
plt.figure(figsize=(17,8),dpi=250)
byDate['AveragePrice'].plot()
plt.title('Average Price')
# Out:
# Text(0.5, 1.0, 'Average Price')

# %%
byMonth = dataset.groupby("Month").mean(numeric_only=True)
plt.figure(figsize=(17,8),dpi=250)
plt.plot(["Jan","Feb","Mar","Apr","May","Jun","Jul","Aug","Sept","Oct","Nov","Dec"],byMonth['AveragePrice'])
plt.title('Average Price Per Month')
# Out:
# Text(0.5, 1.0, 'Average Price Per Month')

# %%
byDay = dataset.groupby("Day").mean(numeric_only=True)
plt.figure(figsize=(17,8),dpi=250)
byDay['AveragePrice'].plot()
plt.title('Average Price Per Day')
# Out:
# Text(0.5, 1.0, 'Average Price Per Day')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(17,8),dpi=250)
sns.barplot(x="region", y="AveragePrice", data=dataset, estimator=lambda x: x.mean(), palette='rocket')
plt.xticks(rotation=90)
plt.xlabel('Region')
plt.ylabel('Average Price')
plt.title('Average Price According to Region')
plt.show()
# Out:
# /var/folders/40/3x72_s6j4qv6w76t662cgbg00000gp/T/ipykernel_56633/1992134695.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="region", y="AveragePrice", data=dataset, estimator=lambda x: x.mean(), palette='rocket')

# %%
plt.figure(figsize=(15,10),dpi=250)
dataset["AveragePrice"].plot(kind="hist",color="blue",bins=30,grid=True,alpha=0.65,label="Average Price")
plt.legend()
plt.xlabel("Average Price")
plt.title("Average Price Distribution")
plt.show()

# %%
import numpy as np

numeric_df = dataset.select_dtypes(include='number')
corr_df = numeric_df.corr(method='pearson')
plt.figure(figsize=(12,6),dpi=250)
sns.heatmap(corr_df,cmap='coolwarm',annot=True)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.catplot(
    x='AveragePrice',
    y='region',
    hue='year',
    data=dataset,       # data는 항상 키워드 인자로
    kind='strip',       # 또는 'swarm', 'box', 'violin'
    height=15,
    aspect=0.8,
    palette='magma',
    dodge=True
)
plt.show()

# %%
dataset_vif = dataset.copy()
dataset_vif.drop(columns=['Date','type','region'],inplace = True)

from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.tools.tools import add_constant

Xf = add_constant(dataset_vif)
pd.Series([variance_inflation_factor(Xf.values, i) 
               for i in range(Xf.shape[1])], 
              index=Xf.columns)
# Out:
# const           5.068485e+06
# AveragePrice    1.099766e+00
# Total Volume    4.918067e+09
# 4046            6.598339e+08
# 4225            5.978631e+08
# 4770            4.762133e+06
# Total Bags      2.370316e+14
# Small Bags      1.364727e+14
# Large Bags      1.448103e+13
# XLarge Bags     7.622174e+10
# year            1.101665e+00
# Month           1.071816e+00
# Day             1.001467e+00
# dtype: float64

# %%
plt.figure(figsize=(15,7),dpi=250)
sns.boxplot(data = dataset[[
 'AveragePrice',
 'Total Volume',
 '4046',
 '4225',
 '4770',
 'Total Bags',
 'Small Bags',
 'Large Bags',
 'XLarge Bags']])
# Out:
# <Axes: >

# %%
dataset.drop(columns=["Date"],inplace=True)
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  18249 non-null  float64
#  1   Total Volume  18249 non-null  float64
#  2   4046          18249 non-null  float64
#  3   4225          18249 non-null  float64
#  4   4770          18249 non-null  float64
#  5   Total Bags    18249 non-null  float64
#  6   Small Bags    18249 non-null  float64
#  7   Large Bags    18249 non-null  float64
#  8   XLarge Bags   18249 non-null  float64
#  9   type          18249 non-null  object
#  10  year          18249 non-null  int64
#  11  region        18249 non-null  object
#  12  Month         18249 non-null  int64
#  13  Day           18249 non-null  int64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 1.9+ MB

# %%
import numpy as np
from numpy import percentile

columns = dataset.columns
for j in columns:
    if isinstance(dataset[j][0], str) :
        continue
    else:
        #defining quartiles
        quartiles = percentile(dataset[j], [25,75])
        # calculate min/max
        lower_fence = quartiles[0] - (1.5*(quartiles[1]-quartiles[0]))
        upper_fence = quartiles[1] + (1.5*(quartiles[1]-quartiles[0]))
        dataset[j] = dataset[j].apply(lambda x: upper_fence if x > upper_fence else (lower_fence if x < lower_fence else x))

# %%
dataset.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags          type  year  region  Month  Day
# 0     8603.62       93.25          0.0  conventional  2015  Albany     12   27
# 1     9408.07       97.49          0.0  conventional  2015  Albany     12   20
# 2     8042.21      103.14          0.0  conventional  2015  Albany     12   13
# 3     5677.40      133.76          0.0  conventional  2015  Albany     12    6
# 4     5986.26      197.69          0.0  conventional  2015  Albany     11   29

# %%
plt.figure(figsize=(15,7),dpi=250)
sns.boxplot(data = dataset[[
 'AveragePrice',
 'Total Volume',
 '4046',
 '4225',
 '4770',
 'Total Bags',
 'Small Bags',
 'Large Bags',
 'XLarge Bags']])
# Out:
# <Axes: >

# %%
dataset['region'] = pd.Categorical(dataset['region'])
dfDummies_region = pd.get_dummies(dataset['region'], prefix = 'region')
dfDummies_region
# Out:
#        region_Albany  region_Atlanta  region_BaltimoreWashington  \
# 0               True           False                       False
# 1               True           False                       False
# 2               True           False                       False
# 3               True           False                       False
# 4               True           False                       False
# ...              ...             ...                         ...
# 18244          False           False                       False
# 18245          False           False                       False
# 18246          False           False                       False
# 18247          False           False                       False
# 18248          False           False                       False
#
#        region_Boise  region_Boston  region_BuffaloRochester  \
# 0             False          False                    False
# 1             False          False                    False
# 2             False          False                    False
# 3             False          False                    False
# 4             False          False                    False
# ...             ...            ...                      ...
# 18244         False          False                    False
# 18245         False          False                    False
# 18246         False          False                    False
# 18247         False          False                    False
# 18248         False          False                    False
#
#        region_California  region_Charlotte  region_Chicago  \
# 0                  False             False           False
# 1                  False             False           False
# 2                  False             False           False
# 3                  False             False           False
# 4                  False             False           False
# ...                  ...               ...             ...
# 18244              False             False           False
# 18245              False             False           False
# 18246              False             False           False
# 18247              False             False           False
# 18248              False             False           False
#
#        region_CincinnatiDayton  ...  region_SouthCarolina  \
# 0                        False  ...                 False
# 1                        False  ...                 False
# 2                        False  ...                 False
# 3                        False  ...                 False
# 4                        False  ...                 False
# ...                        ...  ...                   ...
# 18244                    False  ...                 False
# 18245                    False  ...                 False
# 18246                    False  ...                 False
# 18247                    False  ...                 False
# 18248                    False  ...                 False
#
#        region_SouthCentral  region_Southeast  region_Spokane  region_StLouis  \
# 0                    False             False           False           False
# 1                    False             False           False           False
# 2                    False             False           False           False
# 3                    False             False           False           False
# 4                    False             False           False           False
# ...                    ...               ...             ...             ...
# 18244                False             False           False           False
# 18245                False             False           False           False
# 18246                False             False           False           False
# 18247                False             False           False           False
# 18248                False             False           False           False
#
#        region_Syracuse  region_Tampa  region_TotalUS  region_West  \
# 0                False         False           False        False
# 1                False         False           False        False
# 2                False         False           False        False
# 3                False         False           False        False
# 4                False         False           False        False
# ...                ...           ...             ...          ...
# 18244            False         False           False        False
# 18245            False         False           False        False
# 18246            False         False           False        False
# 18247            False         False           False        False
# 18248            False         False           False        False
#
#        region_WestTexNewMexico
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False
# ...                        ...
# 18244                     True
# 18245                     True
# 18246                     True
# 18247                     True
# 18248                     True
#
# [18249 rows x 54 columns]

# %%
dataset = pd.concat([dataset, dfDummies_region], axis=1)
dataset.drop(columns="region",inplace=True)
dataset
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  ...  \
# 0         8603.62       93.25          0.0  conventional  ...
# 1         9408.07       97.49          0.0  conventional  ...
# 2         8042.21      103.14          0.0  conventional  ...
# 3         5677.40      133.76          0.0  conventional  ...
# 4         5986.26      197.69          0.0  conventional  ...
# ...           ...         ...          ...           ...  ...
# 18244    13066.82      431.85          0.0       organic  ...
# 18245     8940.04      324.80          0.0       organic  ...
# 18246     9351.80       42.31          0.0       organic  ...
# 18247    10919.54       50.00          0.0       organic  ...
# 18248    11988.14       26.01          0.0       organic  ...
#
#        region_SouthCarolina  region_SouthCentral  region_Southeast  \
# 0                     False                False             False
# 1                     False                False             False
# 2                     False                False             False
# 3                     False                False             False
# 4                     False                False             False
# ...                     ...                  ...               ...
# 18244                 False                False             False
# 18245                 False                False             False
# 18246                 False                False             False
# 18247                 False                False             False
# 18248                 False                False             False
#
#        region_Spokane  region_StLouis  region_Syracuse  region_Tampa  \
# 0               False           False            False         False
# 1               False           False            False         False
# 2               False           False            False         False
# 3               False           False            False         False
# 4               False           False            False         False
# ...               ...             ...              ...           ...
# 18244           False           False            False         False
# 18245           False           False            False         False
# 18246           False           False            False         False
# 18247           False           False            False         False
# 18248           False           False            False         False
#
#        region_TotalUS  region_West  region_WestTexNewMexico
# 0               False        False                    False
# 1               False        False                    False
# 2               False        False                    False
# 3               False        False                    False
# 4               False        False                    False
# ...               ...          ...                      ...
# 18244           False        False                     True
# 18245           False        False                     True
# 18246           False        False                     True
# 18247           False        False                     True
# 18248           False        False                     True
#
# [18249 rows x 67 columns]

# %%
dataset['Month'] = pd.Categorical(dataset['Month'])
dfDummies_month = pd.get_dummies(dataset['Month'], prefix = 'month')
dfDummies_month
# Out:
#        month_1  month_2  month_3  month_4  month_5  month_6  month_7  month_8  \
# 0        False    False    False    False    False    False    False    False
# 1        False    False    False    False    False    False    False    False
# 2        False    False    False    False    False    False    False    False
# 3        False    False    False    False    False    False    False    False
# 4        False    False    False    False    False    False    False    False
# ...        ...      ...      ...      ...      ...      ...      ...      ...
# 18244    False     True    False    False    False    False    False    False
# 18245     True    False    False    False    False    False    False    False
# 18246     True    False    False    False    False    False    False    False
# 18247     True    False    False    False    False    False    False    False
# 18248     True    False    False    False    False    False    False    False
#
#        month_9  month_10  month_11  month_12
# 0        False     False     False      True
# 1        False     False     False      True
# 2        False     False     False      True
# 3        False     False     False      True
# 4        False     False      True     False
# ...        ...       ...       ...       ...
# 18244    False     False     False     False
# 18245    False     False     False     False
# 18246    False     False     False     False
# 18247    False     False     False     False
# 18248    False     False     False     False
#
# [18249 rows x 12 columns]

# %%
dataset = pd.concat([dataset, dfDummies_month], axis=1)
dataset.drop(columns="Month",inplace=True)
dataset
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags          type  ...  month_3  \
# 0         8603.62       93.25          0.0  conventional  ...    False
# 1         9408.07       97.49          0.0  conventional  ...    False
# 2         8042.21      103.14          0.0  conventional  ...    False
# 3         5677.40      133.76          0.0  conventional  ...    False
# 4         5986.26      197.69          0.0  conventional  ...    False
# ...           ...         ...          ...           ...  ...      ...
# 18244    13066.82      431.85          0.0       organic  ...    False
# 18245     8940.04      324.80          0.0       organic  ...    False
# 18246     9351.80       42.31          0.0       organic  ...    False
# 18247    10919.54       50.00          0.0       organic  ...    False
# 18248    11988.14       26.01          0.0       organic  ...    False
#
#        month_4  month_5  month_6  month_7  month_8  month_9  month_10  \
# 0        False    False    False    False    False    False     False
# 1        False    False    False    False    False    False     False
# 2        False    False    False    False    False    False     False
# 3        False    False    False    False    False    False     False
# 4        False    False    False    False    False    False     False
# ...        ...      ...      ...      ...      ...      ...       ...
# 18244    False    False    False    False    False    False     False
# 18245    False    False    False    False    False    False     False
# 18246    False    False    False    False    False    False     False
# 18247    False    False    False    False    False    False     False
# 18248    False    False    False    False    False    False     False
#
#        month_11  month_12
# 0         False      True
# 1         False      True
# 2         False      True
# 3         False      True
# 4          True     False
# ...         ...       ...
# 18244     False     False
# 18245     False     False
# 18246     False     False
# 18247     False     False
# 18248     False     False
#
# [18249 rows x 78 columns]

# %%
from sklearn import preprocessing 
 
label_encoder = preprocessing.LabelEncoder() 
dataset['type']= label_encoder.fit_transform(dataset['type']) 
dataset
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags  type  ...  month_3  month_4  \
# 0         8603.62       93.25          0.0     0  ...    False    False
# 1         9408.07       97.49          0.0     0  ...    False    False
# 2         8042.21      103.14          0.0     0  ...    False    False
# 3         5677.40      133.76          0.0     0  ...    False    False
# 4         5986.26      197.69          0.0     0  ...    False    False
# ...           ...         ...          ...   ...  ...      ...      ...
# 18244    13066.82      431.85          0.0     1  ...    False    False
# 18245     8940.04      324.80          0.0     1  ...    False    False
# 18246     9351.80       42.31          0.0     1  ...    False    False
# 18247    10919.54       50.00          0.0     1  ...    False    False
# 18248    11988.14       26.01          0.0     1  ...    False    False
#
#        month_5  month_6  month_7  month_8  month_9  month_10  month_11  \
# 0        False    False    False    False    False     False     False
# 1        False    False    False    False    False     False     False
# 2        False    False    False    False    False     False     False
# 3        False    False    False    False    False     False     False
# 4        False    False    False    False    False     False      True
# ...        ...      ...      ...      ...      ...       ...       ...
# 18244    False    False    False    False    False     False     False
# 18245    False    False    False    False    False     False     False
# 18246    False    False    False    False    False     False     False
# 18247    False    False    False    False    False     False     False
# 18248    False    False    False    False    False     False     False
#
#        month_12
# 0          True
# 1          True
# 2          True
# 3          True
# 4         False
# ...         ...
# 18244     False
# 18245     False
# 18246     False
# 18247     False
# 18248     False
#
# [18249 rows x 78 columns]

# %%
dataset.head()
# Out:
#    AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0          1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1          1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2          0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3          1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4          1.28      51039.60   941.48   43838.39   75.78     6183.95
#
#    Small Bags  Large Bags  XLarge Bags  type  ...  month_3  month_4  month_5  \
# 0     8603.62       93.25          0.0     0  ...    False    False    False
# 1     9408.07       97.49          0.0     0  ...    False    False    False
# 2     8042.21      103.14          0.0     0  ...    False    False    False
# 3     5677.40      133.76          0.0     0  ...    False    False    False
# 4     5986.26      197.69          0.0     0  ...    False    False    False
#
#    month_6  month_7  month_8  month_9  month_10  month_11  month_12
# 0    False    False    False    False     False     False      True
# 1    False    False    False    False     False     False      True
# 2    False    False    False    False     False     False      True
# 3    False    False    False    False     False     False      True
# 4    False    False    False    False     False      True     False
#
# [5 rows x 78 columns]

# %%
X=dataset.iloc[:,1:78]
y=dataset['AveragePrice']
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=50)
y_test = np.array(y_test,dtype = float)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
import sklearn.metrics as metrics

def regression_results(y_true, y_pred):
    explained_variance=metrics.explained_variance_score(y_true, y_pred)
    mean_absolute_error=metrics.mean_absolute_error(y_true, y_pred) 
    mse=metrics.mean_squared_error(y_true, y_pred) 
    r2=metrics.r2_score(y_true, y_pred)
    adjusted_r2 = 1 - (1-r2)*(len(y_true)-1)/(len(y_true)-X_test.shape[1]-1)

    print('Explained_variance: ', round(explained_variance,4))    
    print('R2: ', round(r2,4))
    print('Adjusted_r2: ', round(adjusted_r2,4))
    print('MAE: ', round(mean_absolute_error,4))
    print('MSE: ', round(mse,4))
    print('RMSE: ', round(np.sqrt(mse),4))

# %%
from sklearn.model_selection import cross_val_score
def model_accuracy(model,X_train=X_train,y_train=y_train):
    accuracies = cross_val_score(estimator = model, X = X_train, y = y_train, cv = 10)
    print("Accuracy: {:.2f} %".format(accuracies.mean()*100))
    print("Standard Deviation: {:.2f} %".format(accuracies.std()*100))

# %%
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

regressor=LinearRegression()
regressor.fit(X_train,y_train)
y_pred = regressor.predict(X_test)
regression_results(y_test,y_pred)
model_accuracy(regressor)
# Out:
# Explained_variance:  0.6665
# R2:  0.6664
# Adjusted_r2:  0.6592
# MAE:  0.1779
# MSE:  0.0541
# RMSE:  0.2327
# Accuracy: 64.15 %
# Standard Deviation: 1.48 %

# %%
from yellowbrick.regressor import ResidualsPlot

fig = plt.figure(figsize=(16, 12),dpi=100)
visualizer = ResidualsPlot(regressor, hist = True, qqplot = False)
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# <Axes: title={'center': 'Residuals for LinearRegression Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
from sklearn.ensemble import RandomForestRegressor

rand_regressor = RandomForestRegressor()
rand_regressor.fit(X_train, y_train)
y_pred_rf = rand_regressor.predict(X_test)
regression_results(y_test,y_pred_rf)
model_accuracy(rand_regressor)
# Out:
# Explained_variance:  0.9067
# R2:  0.9067
# Adjusted_r2:  0.9046
# MAE:  0.0885
# MSE:  0.0151
# RMSE:  0.1231
# Accuracy: 88.48 %
# Standard Deviation: 0.49 %

# %%
fig = plt.figure(figsize=(16, 12),dpi=100)
visualizer = ResidualsPlot(rand_regressor, hist = True, qqplot = False)
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()
# Out:
# <Axes: title={'center': 'Residuals for RandomForestRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>

# %%
from sklearn.tree import DecisionTreeRegressor

decision_tree=DecisionTreeRegressor(criterion='squared_error',splitter='random',random_state=10)
decision_tree.fit(X_train, y_train)
y_pred_dt = decision_tree.predict(X_test)
regression_results(y_test,y_pred_dt)
model_accuracy(decision_tree)
# Out:
# Explained_variance:  0.8307
# R2:  0.8307
# Adjusted_r2:  0.827
# MAE:  0.1101
# MSE:  0.0275
# RMSE:  0.1658
# Accuracy: 80.06 %
# Standard Deviation: 1.25 %

# %%
fig = plt.figure(figsize=(16, 12),dpi=100)
visualizer = ResidualsPlot(decision_tree, hist = True, qqplot = False)
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show()                 # Finalize and render the figure
# Out:
# <Axes: title={'center': 'Residuals for DecisionTreeRegressor Model'}, xlabel='Predicted Value', ylabel='Residuals'>
